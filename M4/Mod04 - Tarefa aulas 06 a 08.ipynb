# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio"
dados = requests.get(url)
dados.status_code
# Out:
# 200

# %%
dados_json = dados.json()
dados_json.keys()
# Out:
# dict_keys(['items', 'hasMore', 'limit', 'offset', 'count', 'links'])

# %%
df = pd.DataFrame(dados_json['items'])
df
# Out:
#      id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        60354        Município          Paraty   3303807  RJ
# 1        60039        Município      Petrópolis   3303906  RJ
# 2         7273        Município  Rio de Janeiro   3304557  RJ
# 3        31378        Município      Petrópolis   3303906  RJ
# 4        34100        Município         Resende   3304201  RJ
# ..         ...              ...             ...       ...  ..
# 231      34031        Município        Itatiaia   3302254  RJ
# 232       9101        Município           Piraí   3304003  RJ
# 233      12747        Município         Niterói   3303302  RJ
# 234      13677        Município     Barra Mansa   3300407  RJ
# 235      13690        Município  Rio de Janeiro   3304557  RJ
#
#                   num_pvl                                             status  \
# 0    PVL02.006783/2022-39                                  Deferido (PVL-IF)
# 1    PVL02.005942/2022-88                                           Deferido
# 2                    None                                           Deferido
# 3    PVL02.000583/2019-77                                           Deferido
# 4    PVL02.003091/2019-33                                  Deferido (PVL-IF)
# ..                    ...                                                ...
# 231  PVL02.003023/2019-74                                  Deferido (PVL-IF)
# 232                  None                                          Arquivado
# 233                  None  Encaminhado à PGFN com manifestação técnica fa...
# 234                  None                                           Deferido
# 235                  None                                          Arquivado
#
#              num_processo        data_protocolo  \
# 0                    None                  None
# 1    17944.102384/2022-61  2022-06-21T13:12:44Z
# 2    17944.000536/2007-52  2007-05-30T03:00:00Z
# 3    17944.101202/2019-39  2019-04-11T19:29:03Z
# 4                    None                  None
# ..                    ...                   ...
# 231                  None                  None
# 232  17944.000903/2008-07  2008-04-02T03:00:00Z
# 233  17944.001779/2006-27  2013-12-04T02:00:00Z
# 234  19405.000049/2005-51  2006-05-05T03:00:00Z
# 235  19405.000052/2003-11  2005-05-01T03:00:00Z
#
#                                          tipo_operacao             finalidade  \
# 0                          Operação contratual interna         Infraestrutura
# 1                          Operação contratual interna         Infraestrutura
# 2                          Operação contratual interna  Saneamento para Todos
# 3                          Operação contratual interna                  PNAFM
# 4                          Operação contratual interna      Aporte de capital
# ..                                                 ...                    ...
# 231                        Operação contratual interna         Infraestrutura
# 232                        Operação contratual interna    Caminho da Escola 2
# 233  Operação contratual externa (com garantia da U...         Multissetorial
# 234                        Operação contratual interna                   PMAT
# 235  Operação contratual externa (com garantia da U...         Multissetorial
#
#                               tipo_credor  \
# 0         Instituição Financeira Nacional
# 1         Instituição Financeira Nacional
# 2         Instituição Financeira Nacional
# 3         Instituição Financeira Nacional
# 4         Instituição Financeira Nacional
# ..                                    ...
# 231       Instituição Financeira Nacional
# 232       Instituição Financeira Nacional
# 233  Instituição Financeira Internacional
# 234       Instituição Financeira Nacional
# 235  Instituição Financeira Internacional
#
#                                                 credor          moeda  \
# 0       Agência de Fomento do Estado do Rio de Janeiro           Real
# 1                              Caixa Econômica Federal           Real
# 2                              Caixa Econômica Federal           Real
# 3                              Caixa Econômica Federal           Real
# 4                              Caixa Econômica Federal           Real
# ..                                                 ...            ...
# 231                                Banco do Brasil S/A           Real
# 232                                Banco do Brasil S/A           Real
# 233            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 234  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 235  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#             valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0    4.794057e+06                 0                      1  28/07/2022
# 1    2.000000e+07                 0                      1  23/06/2022
# 2    1.106480e+07                 1                      0  04/06/2007
# 3    9.200000e+06                 1                      1  23/04/2019
# 4    3.600000e+06                 0                      1  27/09/2019
# ..            ...               ...                    ...         ...
# 231  5.000000e+06                 0                      1  17/10/2019
# 232  3.675000e+05                 0                      0  13/08/2008
# 233  2.647000e+07                 1                      0  19/12/2013
# 234  2.669010e+06                 0                      0  15/05/2006
# 235  1.779240e+08                 0                      0  17/08/2006
#
# [236 rows x 18 columns]

# %%
# 2) Seu código aqui
print("Os três status das solicitações mais frequentes e suas respectivas frequências são:")
df['status'].value_counts()[:3]
# Out:
# Os três status das solicitações mais frequentes e suas respectivas frequências são:
# Deferido        94
# Arquivado       53
# Regularizado    25
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
df["ano"] = df["data_status"].str.split("/", 0).str[-1]
df
# Out:
# /tmp/ipykernel_527/3079232537.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df["ano"] = df["data_status"].str.split("/", 0).str[-1]
#      id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        60354        Município          Paraty   3303807  RJ
# 1        60039        Município      Petrópolis   3303906  RJ
# 2         7273        Município  Rio de Janeiro   3304557  RJ
# 3        31378        Município      Petrópolis   3303906  RJ
# 4        34100        Município         Resende   3304201  RJ
# ..         ...              ...             ...       ...  ..
# 231      34031        Município        Itatiaia   3302254  RJ
# 232       9101        Município           Piraí   3304003  RJ
# 233      12747        Município         Niterói   3303302  RJ
# 234      13677        Município     Barra Mansa   3300407  RJ
# 235      13690        Município  Rio de Janeiro   3304557  RJ
#
#                   num_pvl                                             status  \
# 0    PVL02.006783/2022-39                                  Deferido (PVL-IF)
# 1    PVL02.005942/2022-88                                           Deferido
# 2                    None                                           Deferido
# 3    PVL02.000583/2019-77                                           Deferido
# 4    PVL02.003091/2019-33                                  Deferido (PVL-IF)
# ..                    ...                                                ...
# 231  PVL02.003023/2019-74                                  Deferido (PVL-IF)
# 232                  None                                          Arquivado
# 233                  None  Encaminhado à PGFN com manifestação técnica fa...
# 234                  None                                           Deferido
# 235                  None                                          Arquivado
#
#              num_processo        data_protocolo  \
# 0                    None                  None
# 1    17944.102384/2022-61  2022-06-21T13:12:44Z
# 2    17944.000536/2007-52  2007-05-30T03:00:00Z
# 3    17944.101202/2019-39  2019-04-11T19:29:03Z
# 4                    None                  None
# ..                    ...                   ...
# 231                  None                  None
# 232  17944.000903/2008-07  2008-04-02T03:00:00Z
# 233  17944.001779/2006-27  2013-12-04T02:00:00Z
# 234  19405.000049/2005-51  2006-05-05T03:00:00Z
# 235  19405.000052/2003-11  2005-05-01T03:00:00Z
#
#                                          tipo_operacao             finalidade  \
# 0                          Operação contratual interna         Infraestrutura
# 1                          Operação contratual interna         Infraestrutura
# 2                          Operação contratual interna  Saneamento para Todos
# 3                          Operação contratual interna                  PNAFM
# 4                          Operação contratual interna      Aporte de capital
# ..                                                 ...                    ...
# 231                        Operação contratual interna         Infraestrutura
# 232                        Operação contratual interna    Caminho da Escola 2
# 233  Operação contratual externa (com garantia da U...         Multissetorial
# 234                        Operação contratual interna                   PMAT
# 235  Operação contratual externa (com garantia da U...         Multissetorial
#
#                               tipo_credor  \
# 0         Instituição Financeira Nacional
# 1         Instituição Financeira Nacional
# 2         Instituição Financeira Nacional
# 3         Instituição Financeira Nacional
# 4         Instituição Financeira Nacional
# ..                                    ...
# 231       Instituição Financeira Nacional
# 232       Instituição Financeira Nacional
# 233  Instituição Financeira Internacional
# 234       Instituição Financeira Nacional
# 235  Instituição Financeira Internacional
#
#                                                 credor          moeda  \
# 0       Agência de Fomento do Estado do Rio de Janeiro           Real
# 1                              Caixa Econômica Federal           Real
# 2                              Caixa Econômica Federal           Real
# 3                              Caixa Econômica Federal           Real
# 4                              Caixa Econômica Federal           Real
# ..                                                 ...            ...
# 231                                Banco do Brasil S/A           Real
# 232                                Banco do Brasil S/A           Real
# 233            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 234  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 235  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#             valor  pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 0    4.794057e+06                 0                      1  28/07/2022  2022
# 1    2.000000e+07                 0                      1  23/06/2022  2022
# 2    1.106480e+07                 1                      0  04/06/2007  2007
# 3    9.200000e+06                 1                      1  23/04/2019  2019
# 4    3.600000e+06                 0                      1  27/09/2019  2019
# ..            ...               ...                    ...         ...   ...
# 231  5.000000e+06                 0                      1  17/10/2019  2019
# 232  3.675000e+05                 0                      0  13/08/2008  2008
# 233  2.647000e+07                 1                      0  19/12/2013  2013
# 234  2.669010e+06                 0                      0  15/05/2006  2006
# 235  1.779240e+08                 0                      0  17/08/2006  2006
#
# [236 rows x 19 columns]

# %%
#4)
df["ano"].value_counts()
# Out:
# 2008    37
# 2007    29
# 2014    20
# 2010    19
# 2019    17
# 2013    15
# 2020    15
# 2012    13
# 2022    12
# 2011    10
# 2009     9
# 2015     8
# 2017     5
# 2021     5
# 2016     4
# 2018     4
# 2002     4
# 2023     4
# 2006     4
# 2003     1
# 2004     1
# Name: ano, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def Pega_Dados_API(UF, Interessado):
    if (type(Interessado) != str | type(UF) != str):
        print("Os dados devem ser fornecidos no formato string.")
        return
    UF = UF.upper()    
    Interessado = Interessado.capitalize()
 
    if (Interessado == "Estado") | (Interessado == "Município"):
        pass
    elif Interessado == "Municipio":
        Interessado = "Município"
    else:
        print("O campo 'Interessado' deve ser 'Estado' ou 'Município'")
              
    url=f"http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={UF}&tipo_interessado={Interessado}"
    dados = requests.get(url)
    dados_json = dados.json()
    df = pd.DataFrame(dados_json['items'])    
              
    return df

# %%
Pega_Dados_API('ce', 'municipio')
# Out:
#      id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0        44131        Município     Itarema   2306553  CE
# 1        32113        Município      Sobral   2312908  CE
# 2        18480        Município    Pacatuba   2309706  CE
# 3        23721        Município   Fortaleza   2304400  CE
# 4        48137        Município     Tianguá   2313401  CE
# ..         ...              ...         ...       ...  ..
# 261      33690        Município   Fortaleza   2304400  CE
# 262      10821        Município    Tamboril   2313203  CE
# 263       5474        Município   Itapipoca   2306405  CE
# 264      18554        Município     Aquiraz   2301000  CE
# 265      12452        Município   Morrinhos   2308906  CE
#
#                   num_pvl              status          num_processo  \
# 0    PVL02.000423/2021-42   Deferido (PVL-IF)                  None
# 1    PVL02.001284/2019-50   Deferido (PVL-IF)                  None
# 2                    None           Arquivado  19407.000031/2004-58
# 3    PVL02.000644/2016-53  Arquivado pela STN  17944.001264/2016-07
# 4    PVL02.001721/2021-50            Deferido  17944.103782/2021-13
# ..                    ...                 ...                   ...
# 261  PVL02.002120/2019-40            Deferido  17944.102384/2019-65
# 262                  None           Arquivado  17944.001294/2009-86
# 263                  None           Arquivado  17944.000122/2008-12
# 264                  None            Deferido  19407.000049/2006-11
# 265                  None           Arquivado  17944.001689/2009-89
#
#            data_protocolo                                      tipo_operacao  \
# 0                    None                        Operação contratual interna
# 1                    None                        Operação contratual interna
# 2    2004-12-22T02:00:00Z                        Operação contratual interna
# 3    2016-12-23T02:00:00Z  Operação contratual externa (com garantia da U...
# 4    2021-11-08T15:53:16Z                        Operação contratual interna
# ..                    ...                                                ...
# 261  2019-07-03T22:03:28Z                        Operação contratual interna
# 262  2009-10-16T03:00:00Z                        Operação contratual interna
# 263  2008-04-11T03:00:00Z                        Operação contratual interna
# 264  2006-06-30T03:00:00Z                        Operação contratual interna
# 265  2010-07-12T03:00:00Z                        Operação contratual interna
#
#                    finalidade                           tipo_credor  \
# 0              Infraestrutura       Instituição Financeira Nacional
# 1              Infraestrutura       Instituição Financeira Nacional
# 2                       PNAFM       Instituição Financeira Nacional
# 3                     Turismo  Instituição Financeira Internacional
# 4              Pró-Transporte       Instituição Financeira Nacional
# ..                        ...                                   ...
# 261            Multissetorial       Instituição Financeira Nacional
# 262              Provias 2009       Instituição Financeira Nacional
# 263         Caminho da Escola       Instituição Financeira Nacional
# 264                      PMAT       Instituição Financeira Nacional
# 265  Caminho da Escola 2009 A       Instituição Financeira Nacional
#
#                                                 credor          moeda  \
# 0                                  Banco do Brasil S/A           Real
# 1                                  Banco do Brasil S/A           Real
# 2                              Caixa Econômica Federal           Real
# 3                         Corporação Andina de Fomento  Dólar dos EUA
# 4                              Caixa Econômica Federal           Real
# ..                                                 ...            ...
# 261  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 262                                Banco do Brasil S/A           Real
# 263                                Banco do Brasil S/A           Real
# 264                                Banco do Brasil S/A           Real
# 265                                Banco do Brasil S/A           Real
#
#             valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0    3.992900e+06                 0                      1  06/07/2021
# 1    3.552500e+06                 1                      1  19/08/2019
# 2    3.794310e+05                 0                      0  23/12/2004
# 3    1.250000e+08                 0                      0  18/07/2017
# 4    7.379131e+06                 0                      0  11/11/2021
# ..            ...               ...                    ...         ...
# 261  1.452266e+08                 1                      0  08/07/2019
# 262  4.300000e+05                 0                      0  20/01/2011
# 263  8.999190e+05                 0                      0  19/05/2008
# 264  7.690000e+05                 1                      0  29/09/2006
# 265  3.499000e+05                 0                      0  21/01/2011
#
# [266 rows x 18 columns]

# %%
# 2) Seu código aqui
df_mg = Pega_Dados_API('mg', 'estado')
df_mg["status"].value_counts()["Arquivado por decurso de prazo"]
# Out:
# 1

# %%
# 3) Seu código aqui
df_ba = Pega_Dados_API('ba', 'município')
df_ba["interessado"].value_counts().index[0]
# Out:
# 'Camaçari'

# %%
# 4) Seu código aqui
df_ba = Pega_Dados_API('ba', 'estado')
df_ba.to_csv('bahia_estado.csv')
