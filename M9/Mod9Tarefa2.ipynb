# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.set_theme()  
# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df = pd.read_csv('SINASC_RO_2019.csv')
df.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1        2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2        3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3        4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4        5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 69 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        27028 non-null  int64
#  1   CODESTAB      26913 non-null  float64
#  2   CODMUNNASC    27028 non-null  int64
#  3   LOCNASC       27028 non-null  int64
#  4   IDADEMAE      27028 non-null  int64
#  5   ESTCIVMAE     26711 non-null  float64
#  6   ESCMAE        26716 non-null  object
#  7   CODOCUPMAE    24121 non-null  float64
#  8   QTDFILVIVO    25455 non-null  float64
#  9   QTDFILMORT    24930 non-null  float64
#  10  CODMUNRES     27028 non-null  int64
#  11  GESTACAO      25796 non-null  object
#  12  GRAVIDEZ      26949 non-null  object
#  13  PARTO         26979 non-null  object
#  14  CONSULTAS     27028 non-null  int64
#  15  DTNASC        27028 non-null  object
#  16  HORANASC      27007 non-null  float64
#  17  SEXO          27024 non-null  object
#  18  APGAR1        26932 non-null  float64
#  19  APGAR5        26925 non-null  float64
#  20  RACACOR       26381 non-null  object
#  21  PESO          27028 non-null  int64
#  22  IDANOMAL      26437 non-null  float64
#  23  DTCADASTRO    27028 non-null  object
#  24  CODANOMAL     214 non-null    object
#  25  NUMEROLOTE    27028 non-null  int64
#  26  VERSAOSIST    27028 non-null  object
#  27  DTRECEBIM     27028 non-null  object
#  28  DIFDATA       27028 non-null  int64
#  29  DTRECORIGA    0 non-null      float64
#  30  NATURALMAE    26730 non-null  float64
#  31  CODMUNNATU    26730 non-null  float64
#  32  CODUFNATU     26730 non-null  float64
#  33  ESCMAE2010    26779 non-null  float64
#  34  SERIESCMAE    14318 non-null  float64
#  35  DTNASCMAE     26988 non-null  float64
#  36  RACACORMAE    26367 non-null  float64
#  37  QTDGESTANT    25816 non-null  float64
#  38  QTDPARTNOR    25149 non-null  float64
#  39  QTDPARTCES    25237 non-null  float64
#  40  IDADEPAI      7607 non-null   float64
#  41  DTULTMENST    16956 non-null  float64
#  42  SEMAGESTAC    25790 non-null  float64
#  43  TPMETESTIM    25790 non-null  float64
#  44  CONSPRENAT    26098 non-null  float64
#  45  MESPRENAT     24161 non-null  float64
#  46  TPAPRESENT    26763 non-null  float64
#  47  STTRABPART    26081 non-null  float64
#  48  STCESPARTO    26281 non-null  float64
#  49  TPNASCASSI    26967 non-null  float64
#  50  TPFUNCRESP    26961 non-null  float64
#  51  TPDOCRESP     27014 non-null  float64
#  52  DTDECLARAC    26976 non-null  float64
#  53  ESCMAEAGR1    26779 non-null  float64
#  54  STDNEPIDEM    27028 non-null  int64
#  55  STDNNOVA      27028 non-null  int64
#  56  CODPAISRES    27028 non-null  int64
#  57  TPROBSON      27028 non-null  int64
#  58  PARIDADE      27028 non-null  int64
#  59  KOTELCHUCK    27028 non-null  int64
#  60  CONTADOR      27028 non-null  int64
#  61  munResStatus  27028 non-null  object
#  62  munResTipo    27028 non-null  object
#  63  munResNome    27028 non-null  object
#  64  munResUf      27028 non-null  object
#  65  munResLat     27027 non-null  float64
#  66  munResLon     27027 non-null  float64
#  67  munResAlt     27027 non-null  float64
#  68  munResArea    27027 non-null  float64
# dtypes: float64(38), int64(16), object(15)
# memory usage: 14.2+ MB

# %% [markdown]
# # Tarefa 2

# %% [markdown]
# ### 1. Crie 2 faixas de Latitude do município (munResLat) sendo uma acima e outra abaixo de -10.5 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
faixa_min = df['munResLat'].min()
faixa_max = df['munResLat'].max()
faixa_total = df['munResLat'].dropna()

faixa_lat = pd.cut(faixa_total, [faixa_min, -10.50000, faixa_max], include_lowest=True)
faixa_lat.isna().sum()
# Out:
# 0

# %%
faixa_lat.unique()
# Out:
# [(-13.501, -10.5], (-10.5, -8.769]]
# Categories (2, interval[float64, right]): [(-13.501, -10.5] < (-10.5, -8.769]]

# %%
pivot1 = df.pivot_table(['QTDPARTNOR', 'QTDPARTCES'],
                        faixa_lat,
                        aggfunc=['sum', 'mean', 'min', 'max', 'median', 'std', 'var']
                       )

# %%
pivot1
# Out:
#                         sum                  mean                   min  \
#                  QTDPARTCES QTDPARTNOR QTDPARTCES QTDPARTNOR QTDPARTCES
# munResLat
# (-13.501, -10.5]     7095.0     5800.0   0.552570   0.452242        0.0
# (-10.5, -8.769]      6041.0     8771.0   0.487335   0.711759        0.0
#
#                                    max                median             \
#                  QTDPARTNOR QTDPARTCES QTDPARTNOR QTDPARTCES QTDPARTNOR
# munResLat
# (-13.501, -10.5]        0.0       12.0       41.0        0.0        0.0
# (-10.5, -8.769]         0.0       12.0       40.0        0.0        0.0
#
#                         std                   var
#                  QTDPARTCES QTDPARTNOR QTDPARTCES QTDPARTNOR
# munResLat
# (-13.501, -10.5]   0.753036   1.123426   0.567062   1.262087
# (-10.5, -8.769]    0.737899   1.279042   0.544495   1.635949

# %% [markdown]
# ### 2. Crie 2 faixas da área dos municípios (munResArea) sendo uma acima e outra abaixo de 3000 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
faixa_min = df['munResArea'].min()
faixa_max = df['munResArea'].max()
faixa_total = df['munResArea'].dropna()

faixa_area = pd.cut(faixa_total, [faixa_min, 3000, faixa_max], include_lowest=True)
faixa_area.isna().sum()
# Out:
# 0

# %%
df.groupby(faixa_area)[['QTDPARTNOR', 'QTDPARTCES']].agg(['sum', 'mean', 'min', 'max', 'median', 'std', 'var'])
# Out:
#                              QTDPARTNOR                                        \
#                                     sum      mean  min   max median       std
# munResArea
# (459.97700000000003, 3000.0]     1912.0  0.371334  0.0  10.0    0.0  0.856441
# (3000.0, 34096.394]             12659.0  0.632982  0.0  41.0    0.0  1.278932
#
#                                        QTDPARTCES                              \
#                                    var        sum      mean  min   max median
# munResArea
# (459.97700000000003, 3000.0]  0.733490     2952.0  0.572981  0.0   5.0    0.0
# (3000.0, 34096.394]           1.635668    10184.0  0.507070  0.0  12.0    0.0
#
#
#                                    std       var
# munResArea
# (459.97700000000003, 3000.0]  0.749368  0.561553
# (3000.0, 34096.394]           0.744981  0.554997

# %% [markdown]
# ### 3. Determine faixas na variável munResAlt e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
faixa_total = df['munResAlt'].dropna()
faixa_alt = pd.qcut(faixa_total, 3)

# %%
df.groupby(faixa_alt)[['QTDPARTNOR', 'QTDPARTCES']].agg(['sum', 'mean', 'min', 'max', 'median', 'std', 'var'])
# Out:
#                 QTDPARTNOR                                                  \
#                        sum      mean  min   max median       std       var
# munResAlt
# (84.999, 111.0]     6271.0  0.802534  0.0  40.0    0.0  1.377551  1.897646
# (111.0, 177.0]      5336.0  0.574319  0.0  14.0    0.0  1.139346  1.298109
# (177.0, 595.0]      2964.0  0.368519  0.0  41.0    0.0  1.065716  1.135751
#
#                 QTDPARTCES
#                        sum      mean  min   max median       std       var
# munResAlt
# (84.999, 111.0]     3522.0  0.451654  0.0  12.0    0.0  0.736842  0.542936
# (111.0, 177.0]      4788.0  0.510611  0.0  12.0    0.0  0.744376  0.554095
# (177.0, 595.0]      4826.0  0.598685  0.0   5.0    0.0  0.750578  0.563368

# %% [markdown]
# ### 4. Plote no mesmo grafico ao longo do tempo a idade media das mulheres de cada regiao imediatas de rondonia
# https://pt.wikipedia.org/wiki/Lista_de_regi%C3%B5es_geogr%C3%A1ficas_intermedi%C3%A1rias_e_imediatas_de_Rond%C3%B4nia

# %%
regioes = {
    "Rio Crespo": "Ariquemes",
    "Monte Negro": "Ariquemes",
    "Cujubim": "Ariquemes",
    "Campo Novo de Rondônia": "Ariquemes",
    "Cacaulândia": "Ariquemes",
    "Buritis": "Ariquemes",
    "Ariquemes": "Ariquemes",
    "Alto Paraíso": "Ariquemes",
    "Vale do Anari": "Jaru",
    "Theobroma": "Jaru",
    "Machadinho d'Oeste": "Jaru",
    "Jaru": "Jaru",
    "Governador Jorge Teixeira": "Jaru",
    "Porto Velho": "Porto Velho",
    "Nova Mamoré": "Porto Velho",
    "Itapuã do Oeste": "Porto Velho",
    "Guajará-Mirim": "Porto Velho",
    "Candeias do Jamari": "Porto Velho",
    "Alta Floresta d'Oeste": "Cacoal",
    "Alto Alegre dos Parecis": "Cacoal",
    "Cacoal": "Cacoal",
    "Castanheiras": "Cacoal",
    "Espigão d'Oeste": "Cacoal",
    "Ministro Andreazza": "Cacoal",
    "Nova Brasilândia d'Oeste": "Cacoal",
    "Novo Horizonte do Oeste": "Cacoal",
    "Parecis": "Cacoal",
    "Pimenta Bueno": "Cacoal",
    "Primavera de Rondônia": "Cacoal",
    "Rolim de Moura": "Cacoal",
    "Santa Luzia d'Oeste": "Cacoal",
    "São Felipe d'Oeste": "Cacoal",
    "Alvorada d'Oeste": "Ji-Paraná", 
    "Costa Marques": "Ji-Paraná", 
    "Ji-Paraná": "Ji-Paraná", 
    "Mirante da Serra": "Ji-Paraná", 
    "Nova União": "Ji-Paraná", 
    "Ouro Preto do Oeste": "Ji-Paraná", 
    "Presidente Médici": "Ji-Paraná", 
    "São Francisco do Guaporé": "Ji-Paraná", 
    "São Miguel do Guaporé": "Ji-Paraná", 
    "Seringueiras": "Ji-Paraná", 
    "Teixeirópolis": "Ji-Paraná", 
    "Urupá": "Ji-Paraná", 
    "Vale do Paraíso": "Ji-Paraná", 
    "Cabixi": "Vilhena",
    "Cerejeiras": "Vilhena",
    "Chupinguaia": "Vilhena",
    "Colorado do Oeste": "Vilhena",
    "Corumbiara": "Vilhena",
    "Pimenteiras do Oeste": "Vilhena",
    "Vilhena": "Vilhena"
}

# %%
map1 = df.loc[:, ["IDADEMAE", "munResNome", "DTNASC"]]
map1.loc[:, "DTNASCT"] = pd.to_datetime(map1["DTNASC"])
map1 = map1.set_index("munResNome")

# %%
map1.groupby([regioes, "DTNASC"]).mean().unstack().T.plot(figsize=[15,5])
# Out:
# /tmp/ipykernel_486/570219902.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   map1.groupby([regioes, "DTNASC"]).mean().unstack().T.plot(figsize=[15,5])
# <Axes: xlabel='None,DTNASC'>

# %% [markdown]
# ### 5. Utilize a tabela do link abaixo e crie faixas utilizando o mapping e gere agrupamentos utilizando essas faixas como chave

# %% [markdown]
# ### 5.1 IDH
# A - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IDH-M

# %%
idh_rond = pd.read_html("https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IDH-M",header=1)
idh_rond = idh_rond[0].drop([0, 1, 2, 10, 47, 57, 58])
idh_rond = idh_rond.reset_index(drop=True)
idh_rond
# Out:
#    Posição                  Município IDH municipal IDH renda IDH longevidade  \
# 0        1                Porto Velho         0.736     0.764           0.819
# 1        2                    Vilhena         0.731     0.734           0.808
# 2        3                     Cacoal         0.718     0.727           0.821
# 3        4                  Ji-Paraná         0.714     0.728           0.810
# 4        5              Pimenta Bueno         0.710     0.726           0.803
# 5        6                  Ariquemes         0.702     0.716           0.806
# 6        7             Rolim de Moura         0.700     0.709           0.808
# 7        8                 Cerejeiras         0.692     0.688           0.799
# 8        9                       Jaru         0.689     0.687           0.825
# 9       10          Colorado do Oeste         0.685     0.676           0.814
# 10      11        Ouro Preto do Oeste         0.682     0.687           0.812
# 11      12            Espigão d'Oeste         0.672     0.691           0.819
# 12      13        Santa Luzia d'Oeste         0.670     0.657           0.812
# 13      14       Pimenteiras do Oeste         0.665     0.662           0.816
# 14      15          Presidente Médici         0.664     0.671           0.792
# 15      16               Castanheiras         0.658     0.650           0.803
# 16      17              Guajará-Mirim         0.657     0.663           0.823
# 17      18                Chupinguaia         0.652     0.659           0.820
# 18      19                     Cabixi         0.650     0.650           0.757
# 19      20         Candeias do Jamari         0.649     0.652           0.819
# 20      20         São Felipe d'Oeste         0.649     0.615           0.780
# 21      22                Cacaulândia         0.646     0.664           0.801
# 22      22      São Miguel do Guaporé         0.646     0.644           0.781
# 23      24           Mirante da Serra         0.643     0.673           0.800
# 24      24           Alvorada d'Oeste         0.643     0.654           0.763
# 25      24              Teixeirópolis         0.643     0.653           0.818
# 26      24   Nova Brasilândia d'Oeste         0.643     0.664           0.763
# 27      24                 Rio Crespo         0.643     0.637           0.813
# 28      29      Primavera de Rondônia         0.641     0.645           0.799
# 29      29      Alta Floresta d'Oeste         0.641     0.657           0.763
# 30      31         Ministro Andreazza         0.638     0.647           0.776
# 31      32    Novo Horizonte do Oeste         0.634     0.606           0.799
# 32      33            Vale do Paraíso         0.627     0.641           0.792
# 33      34               Alto Paraíso         0.625     0.664           0.804
# 34      35                    Parecis         0.617     0.604           0.800
# 35      36                    Buritis         0.616     0.650           0.751
# 36      37            Itapuã do Oeste         0.614     0.633           0.751
# 37      38                 Corumbiara         0.613     0.630           0.774
# 38      39                    Cujubim         0.612     0.663           0.789
# 39      40              Costa Marques         0.611     0.616           0.751
# 40      40   São Francisco do Guaporé         0.611     0.657           0.751
# 41      42                      Urupá         0.609     0.621           0.772
# 42      43                Monte Negro         0.607     0.645           0.762
# 43      44               Seringueiras         0.598     0.644           0.779
# 44      45  Governador Jorge Teixeira         0.596     0.627           0.762
# 45      45         Machadinho d'Oeste         0.596     0.629           0.755
# 46      47     Campo Novo de Rondônia         0.593     0.667           0.772
# 47      48    Alto Alegre dos Parecis         0.592     0.603           0.777
# 48      49                  Theobroma         0.589     0.622           0.757
# 49      50                 Nova União         0.587     0.608           0.753
# 50      50                Nova Mamoré         0.587     0.619           0.769
# 51      52              Vale do Anari         0.584     0.626           0.756
#
#    IDH educação
# 0         0.638
# 1         0.659
# 2         0.620
# 3         0.617
# 4         0.613
# 5         0.600
# 6         0.598
# 7         0.602
# 8         0.577
# 9         0.584
# 10        0.569
# 11        0.536
# 12        0.564
# 13        0.545
# 14        0.550
# 15        0.547
# 16        0.519
# 17        0.514
# 18        0.559
# 19        0.512
# 20        0.571
# 21        0.506
# 22        0.537
# 23        0.494
# 24        0.534
# 25        0.498
# 26        0.524
# 27        0.513
# 28        0.512
# 29        0.526
# 30        0.518
# 31        0.527
# 32        0.485
# 33        0.457
# 34        0.485
# 35        0.479
# 36        0.488
# 37        0.473
# 38        0.439
# 39        0.493
# 40        0.462
# 41        0.471
# 42        0.454
# 43        0.427
# 44        0.444
# 45        0.446
# 46        0.404
# 47        0.443
# 48        0.434
# 49        0.442
# 50        0.424
# 51        0.421

# %%
idh_rond[["IDH municipal", "IDH renda", "IDH longevidade", "IDH educação"]] = idh_rond[["IDH municipal", "IDH renda", "IDH longevidade", "IDH educação"]].astype('float64')
idh_rond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Posição          52 non-null     object
#  1   Município        52 non-null     object
#  2   IDH municipal    52 non-null     float64
#  3   IDH renda        52 non-null     float64
#  4   IDH longevidade  52 non-null     float64
#  5   IDH educação     52 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 2.6+ KB

# %%
idh_class = {
    "(0.8, 1.0]": "IDH muito alto",
    "(0.7, 0.8]": "IDH alto",
    "(0.6, 0.7]": "IDH médio",
    "(0.5, 0.6]": "IDH baixo",
    "(0.0, 0.5]": "IDH muito baixo",
}

# %%
faixas_idh = pd.cut(idh_rond['IDH municipal'], [0, 0.5, 0.6, 0.7, 0.8, 1], include_lowest=True)
faixas_idh.unique()
# Out:
# [(0.7, 0.8], (0.6, 0.7], (0.5, 0.6]]
# Categories (5, interval[float64, right]): [(-0.001, 0.5] < (0.5, 0.6] < (0.6, 0.7] < (0.7, 0.8] < (0.8, 1.0]]

# %%
idh_rond["IDH classificacao"] = faixas_idh
idh_rond["IDH classificacao"] = idh_rond["IDH classificacao"].astype("string")
idh_rond["IDH classificacao"][0]
# Out:
# '(0.7, 0.8]'

# %%
idh_group = idh_rond.set_index('IDH classificacao')
idh_group.groupby(idh_class).mean()
# Out:
# /tmp/ipykernel_486/538579953.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   idh_group.groupby(idh_class).mean()
#                    IDH municipal  IDH renda  IDH longevidade  IDH educação
# IDH classificacao
# IDH alto                0.718500   0.732500         0.811167      0.624500
# IDH baixo               0.591333   0.627222         0.764444      0.431667
# IDH médio               0.644784   0.653649         0.791135      0.519514

# %% [markdown]
# ### 5.2 IFDM
# B - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IFDM

# %%
ifdm_rond = pd.read_html("https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IFDM", header=0)
ifdm_rond[0]
ifdm_rond = ifdm_rond[0].drop([0, 1, 2, 29, 56, 57])
ifdm_rond = ifdm_rond.reset_index(drop=True)
ifdm_rond["IFDM Consolidado (2013)"] = ifdm_rond["IFDM Consolidado (2013)"].astype("float64")
ifdm_rond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Posição                  52 non-null     object
#  1   Município                52 non-null     object
#  2   IFDM Consolidado (2013)  52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
ifdm_class = {
    "(0.8, 1.0]": "Alto",
    "(0.6, 0.8]": "Moderado",
    "(0.4, 0.6]": "Regular",
    "(0.0, 0.4]": "Baixo",
}

# %%
faixas_ifdm = pd.cut(ifdm_rond['IFDM Consolidado (2013)'], [0, 0.4, 0.6, 0.8, 1], include_lowest=True)
faixas_ifdm.unique()
# Out:
# [(0.6, 0.8], (0.4, 0.6]]
# Categories (4, interval[float64, right]): [(-0.001, 0.4] < (0.4, 0.6] < (0.6, 0.8] < (0.8, 1.0]]

# %%
ifdm_rond["IFDM classificacao"] = faixas_ifdm
ifdm_rond["IFDM classificacao"] = ifdm_rond["IFDM classificacao"].astype("string")
ifdm_rond["IFDM classificacao"][0]
# Out:
# '(0.6, 0.8]'

# %%
ifdm_group = ifdm_rond.set_index('IFDM classificacao')
ifdm_group.groupby(ifdm_class).mean()
# Out:
# /tmp/ipykernel_486/855402434.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ifdm_group.groupby(ifdm_class).mean()
#                     IFDM Consolidado (2013)
# IFDM classificacao
# Moderado                           0.659919
# Regular                            0.556362

# %% [markdown]
# ### 5.3 PIB
# C - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_PIB

# %%
pib_rond = pd.read_html("https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_PIB", header=0)
pib_rond = pd.concat([pib_rond[0], pib_rond[1], pib_rond[2], pib_rond[3], pib_rond[4], pib_rond[5]])
pib_rond = pib_rond.reset_index(drop=True)
pib_rond = pib_rond.drop([0, 9, 19, 27, 32, 49]).reset_index(drop=True)
pib_rond = pib_rond.drop(["Posição.1", "Alteração"], axis=1)
pib_rond['PIB'] = pib_rond['PIB'].str.replace(" ", "").astype("float64")
pib_rond
# Out:
#    Posição                  Município         PIB
# 0        1                Porto Velho  17912070.0
# 1        2                  Ji-Paraná   3783972.0
# 2        3                    Vilhena   2831175.0
# 3        4                  Ariquemes   2579830.0
# 4        5                     Cacoal   2261644.0
# 5        6                       Jaru   1500890.0
# 6        7             Rolim de Moura   1283434.0
# 7        8              Pimenta Bueno   1164877.0
# 8        9              Guajará-Mirim    893000.0
# 9       10        Ouro Preto do Oeste    834000.0
# 10      11                    Buritis    726000.0
# 11      12        Machadinho do Oeste    633000.0
# 12      13            Espigão d'Oeste    625000.0
# 13      14      São Miguel do Guaporé    616000.0
# 14      15         Candeias do Jamari    548000.0
# 15      16                Nova Mamoré    529000.0
# 16      17                 Cerejeiras    507000.0
# 17      18     Alta Floresta do Oeste    496000.0
# 18      19          Presidente Médici    428000.0
# 19      20                    Cujubim    385000.0
# 20      21  Nova Brasilândia do Oeste    360000.0
# 21      22               Alto Paraíso    358000.0
# 22      23   São Francisco do Guaporé    353000.0
# 23      24          Colorado do Oeste    335000.0
# 24      25                Monte Negro    219152.0
# 25      26    Alto Alegre dos Parecis    213410.0
# 26      27     Campo Novo de Rondônia    208821.0
# 27      28          Alvorada do Oeste    204098.0
# 28      29                Chupinguaia    190331.0
# 29      30                 Corumbiara    188218.0
# 30      31         Ministro Andreazza    174633.0
# 31      32                      Urupá    172143.0
# 32      33              Costa Marques    171878.0
# 33      34               Seringueiras    169429.0
# 34      35           Mirante da Serra    163955.0
# 35      36  Governador Jorge Teixeira    148027.0
# 36      37                  Theobroma    140601.0
# 37      38       Santa Luzia do Oeste    135934.0
# 38      39    Novo Horizonte do Oeste    129399.0
# 39      40            Itapuã do Oeste    129351.0
# 40      41            Vale do Paraíso    116742.0
# 41      42                Cacaulândia    116635.0
# 42      43                     Cabixi    113031.0
# 43      44              Vale do Anari    105208.0
# 44      45                 Nova União     92346.0
# 45      46                    Parecis     80759.0
# 46      47                 Rio Crespo     76854.0
# 47      48       Pimenteiras do Oeste     76756.0
# 48      49              Teixeirópolis     72089.0
# 49      50        São Felipe do Oeste     72084.0
# 50      51               Castanheiras     59779.0
# 51      52      Primavera de Rondônia     52908.0

# %%
pib_class = {
    "(-0.001, 100000.0]": "Até 100 milhões",
    "(100000.0, 200000.0]": "Acima de 100 milhões",
    "(200000.0, 300000.0]": "Acima de 200 milhões",
    "(300000.0, 500000.0]": "Acima de 300 milhões",
    "(500000.0, 1000000.0]": "Acima de 500 milhões",
    "(1000000.0, 17912070.0]": "Acima de 1 bilhão"
}

# %%
pib_max = pib_rond['PIB'].max()
faixas_pib = pd.cut(pib_rond['PIB'], [0, 100000, 200000, 300000, 500000, 1000000, pib_max], include_lowest=True)
faixas_pib.unique()
# Out:
# [(1000000.0, 17912070.0], (500000.0, 1000000.0], (300000.0, 500000.0], (200000.0, 300000.0], (100000.0, 200000.0], (-0.001, 100000.0]]
# Categories (6, interval[float64, right]): [(-0.001, 100000.0] < (100000.0, 200000.0] < (200000.0, 300000.0] < (300000.0, 500000.0] < (500000.0, 1000000.0] < (1000000.0, 17912070.0]]

# %%
pib_rond['PIB classificacao'] = faixas_pib
pib_rond['PIB classificacao'] = pib_rond['PIB classificacao'].astype("string")
pib_rond['PIB classificacao'][0]
# Out:
# '(1000000.0, 17912070.0]'

# %%
pib_group = pib_rond.set_index('PIB classificacao')
pib_group.groupby(pib_class).mean().round(2)
# Out:
# /tmp/ipykernel_486/2869633639.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pib_group.groupby(pib_class).mean().round(2)
#                              PIB
# PIB classificacao
# Acima de 1 bilhão     4164736.50
# Acima de 100 milhões   147844.69
# Acima de 200 milhões   211370.25
# Acima de 300 milhões   387857.14
# Acima de 500 milhões   656777.78
# Até 100 milhões         72946.88

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios com o PIB mais alto é a maior dentre todas.

# %%
df[df['ESCMAE'] == "12 anos ou mais"].groupby(["munResNome"])['ESCMAE'].count().sort_values(ascending=False).to_frame()
# Out:
#                            ESCMAE
# munResNome
# Porto Velho                  1990
# Ji-Paraná                     486
# Vilhena                       471
# Cacoal                        403
# Ariquemes                     356
# Rolim de Moura                271
# Jaru                          169
# Ouro Preto do Oeste           152
# Pimenta Bueno                 142
# Guajará-Mirim                  98
# Buritis                        87
# Machadinho D'Oeste             87
# Alta Floresta D'Oeste          83
# Espigão D'Oeste                74
# Cerejeiras                     72
# Colorado do Oeste              70
# São Miguel do Guaporé          62
# Presidente Médici              44
# São Francisco do Guaporé       43
# Nova Brasilândia D'Oeste       42
# Candeias do Jamari             38
# Chupinguaia                    29
# Nova Mamoré                    29
# Urupá                          28
# Alvorada D'Oeste               27
# Monte Negro                    27
# Cujubim                        26
# Alto Paraíso                   26
# Mirante da Serra               23
# Alto Alegre dos Parecis        23
# Corumbiara                     23
# Campo Novo de Rondônia         23
# Cabixi                         22
# Costa Marques                  21
# Ministro Andreazza             20
# Santa Luzia D'Oeste            19
# Novo Horizonte do Oeste        18
# Seringueiras                   17
# Vale do Anari                  15
# São Felipe D'Oeste             12
# Nova União                     11
# Governador Jorge Teixeira      10
# Itapuã do Oeste                10
# Primavera de Rondônia          10
# Cacaulândia                    10
# Teixeirópolis                   9
# Vale do Paraíso                 9
# Rio Crespo                      8
# Theobroma                       7
# Castanheiras                    5
# Pimenteiras do Oeste            5
# Parecis                         5

# %% [markdown]
# ### Análise
#
# As 4 primeiras cidades com o maior número de mães com escolaridade alta (12 ou mais anos) são também as 4 primeiras cidades com o maior IDH municipal.
